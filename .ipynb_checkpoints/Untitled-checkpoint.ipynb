# %%
import pandas as pd
import requests

# %%
PLAYER_ENDPOINT = 'https://armchairanalysis.com/api/1.0/drives/ATL'

# %%
auth = 'Basic bGVpc3lyaWRsZXlAZ21haWwuY29tOnkyTU1OOQ=='

# %%
r = requests.get(PLAYER_ENDPOINT, headers={'Authorization':auth})
json_dump = r.json()
df = pd.DataFrame(json_dump['data'])

# %%
df
# Out:
#      drvn    fpid   gid  min  net   obt  ofd  pa  pc  peya  ...  qtr  ra  \
# 0       1      12     1    2   20  KOFF    0   2   0     0  ...    1   3
# 1       2      23     1    4   37  PUNT    0   6   3     5  ...    1   3
# 2       3      40     1    5   53  PUNT    1   5   2     0  ...    1   5
# 3       4      58     1    2   22  PUNT    0   2   0     0  ...    2   3
# 4       5      71     1    2   62  PUNT    0   3   2     0  ...    2   2
# 5       6      88     1    1   52  KOFF    0   5   4     0  ...    2   1
# 6       7      97     1    0   60  KOFF    0   1   1     0  ...    3   1
# 7       8     114     1    2   10  KOFF    0   3   1     0  ...    3   2
# 8       9     132     1    2   25  PUNT    0   1   1     0  ...    3   3
# 9      10     150     1    3   16  DWNS    0   2   1     0  ...    4   4
# 10     11     161     1    2   22  KOFF    0   1   1     0  ...    4   5
# 11      1    2952    19    2    1  KOFF    0   1   0    10  ...    1   2
# ...

# %%
from endpoints import endpoints

# %%
import grabber

# %%
t = grabber.Grabber('game_stats')

# %%
t.sub
# Out:
# {'endpoint': 'teams',
#  'id': '',
#  'filter_by': 'team_name_abv',
#  'team_name_abv': '',
#  'ext_params': ''}

# %%
t.set_team_name('ATL')

# %%
t.team_name
# Out:
# 'ATL'

# %%
t.ids
# Out:
# 'blocks'

# %%
data.get('blocks')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fac1d145a73e> in <module>
# ----> 1 data.get('blocks')
#
# NameError: name 'data' is not defined

# %%
data = endpoints['data']

# %%
sub = data['blocks']

# %%
sub
# Out:
# {'endpoint': 'games',
#  'id': 'blocks',
#  'filter_by': 'season',
#  'season': 2000,
#  'start': 1,
#  'ext_params': ''}

# %%
sub['id']
# Out:
# 'blocks'

# %%
endpoints['data']['injuries'].get('id')
# Out:
# 'injuries'
